# %%
import pandas as pd

# %% [markdown]
# ## 1. load the dataset into a pandas dataframe. Name the variable as Survey

# %%
df = pd.read_csv('./Survey Dataset.csv')
df
# Out:
#       response_id collection_date urban_rural               education  \
# 0               1       5-24-2017       Rural               12th Pass
# 1               2       5-24-2017       Rural                Graduate
# 2               3       5-24-2017       Rural                Graduate
# 3               4       5-24-2017       Urban                Graduate
# 4               5       5-24-2017       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6862         6863        6-1-2017       Rural               10th Pass
# 6863         6864        6-1-2017       Rural                Graduate
# 6864         6865        6-1-2017       Urban                Graduate
# 6865         6866        6-1-2017       Rural  Professional Education
# 6866         6867        6-1-2017       Rural               10th Pass
#
#                    income Vote_Now     Past_Vote     CM_satisfaction  \
# ...

# %% [markdown]
# ## 2. How many samples were collected on each day

# %%
df['collection_date'].value_counts()
# Out:
# 5-24-2017    1479
# 5-25-2017     998
# 5-28-2017     761
# 5-27-2017     665
# 5-29-2017     620
# 6-1-2017      607
# 5-26-2017     598
# 5-30-2017     582
# 5-31-2017     557
# Name: collection_date, dtype: int64

# %% [markdown]
# ## 3. What proportion of the total respondents were aged less than 45?

# %%
df.head()
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2       5-24-2017       Rural   Graduate  ₹ 20,000 - ₹ 30,000
# 2            3       5-24-2017       Rural   Graduate   ₹ 5,000 - ₹ 10,000
# 3            4       5-24-2017       Urban   Graduate  ₹ 10,000 - ₹ 20,000
# 4            5       5-24-2017       Rural   Graduate  ₹ 50,000 - ₹ 80,000
#
#   Vote_Now     Past_Vote     CM_satisfaction    MLA_satisfaction age gender  \
# 0      BJP           BJP  Fully Dissatisfied  Fully Dissatisfied  26   Male
# 1     RLSP         JD(U)  Somewhat Satisfied  Fully Dissatisfied  34   Male
# 2   JAP(L)           BJP  Fully Dissatisfied  Somewhat Satisfied  25   Male
# 3      RJD           RJD  Fully Dissatisfied  Somewhat Satisfied  36   Male
# 4    JD(U)  Did not vote     Fully Satisfied     Fully Satisfied  22   Male
#
#    assembly_no category    weight
# ...

# %%
df['age'] < 45
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8720\394569110.py in <module>
# ----> 1 df['age']<45
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      68         other = item_from_zerodim(other)
#      69
# ---> 70         return method(self, other)
#      71
#      72     return new_method
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\arraylike.py in __lt__(self, other)
#      46     @unpack_zerodim_and_defer("__lt__")
#      47     def __lt__(self, other):
# ---> 48         return self._cmp_method(other, operator.lt)
#      49
#      50     @unpack_zerodim_and_defer("__le__")
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in _cmp_method(self, other, op)
#    5621
#    5622         with np.errstate(all="ignore"):
# ...

# %%
df.age.unique()
# Out:
# array(['26', '34', '25', '36', '22', '38', '23', '42', '51', '29', '24',
#        '30', '39', '37', '19', '44', '53', '32', '21', '18', '20', '27',
#        '48', '28', '45', '74', '35', '31', '70', '40', '49', '46', '43',
#        '41', '33', '58', '24ko', '56', '50', '55', '54', '62', '60', '59',
#        '47', '61', '52', '66', '57', '67', '65', '71', '63', '64', '68',
#        '69', '99', '72', '75', '76'], dtype=object)

# %%
df['age'].replace({'24ko': '24'}, inplace =True)

# %%
df.age.unique()
# Out:
# array(['26', '34', '25', '36', '22', '38', '23', '42', '51', '29', '24',
#        '30', '39', '37', '19', '44', '53', '32', '21', '18', '20', '27',
#        '48', '28', '45', '74', '35', '31', '70', '40', '49', '46', '43',
#        '41', '33', '58', '56', '50', '55', '54', '62', '60', '59', '47',
#        '61', '52', '66', '57', '67', '65', '71', '63', '64', '68', '69',
#        '99', '72', '75', '76'], dtype=object)

# %%
df['age'] = pd.to_numeric(df['age'])

# %%
df['age'].dtype
# Out:
# dtype('int64')

# %%
df[df['age'] < 45]
# Out:
#       response_id collection_date urban_rural               education  \
# 0               1       5-24-2017       Rural               12th Pass
# 1               2       5-24-2017       Rural                Graduate
# 2               3       5-24-2017       Rural                Graduate
# 3               4       5-24-2017       Urban                Graduate
# 4               5       5-24-2017       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6862         6863        6-1-2017       Rural               10th Pass
# 6863         6864        6-1-2017       Rural                Graduate
# 6864         6865        6-1-2017       Urban                Graduate
# 6865         6866        6-1-2017       Rural  Professional Education
# 6866         6867        6-1-2017       Rural               10th Pass
#
#                    income Vote_Now     Past_Vote     CM_satisfaction  \
# ...

# %%
total_respondants = 6867
respondants_below_45 = 6399

proportion = respondants_below_45/total_respondants*100
proportion
# Out:
# 93.18479685452162

# %% [markdown]
# ## 4. Create new column in datafrome " age_group "

# %%
df.insert(10,'age_group', df.age)

# %%
df.head()
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2       5-24-2017       Rural   Graduate  ₹ 20,000 - ₹ 30,000
# 2            3       5-24-2017       Rural   Graduate   ₹ 5,000 - ₹ 10,000
# 3            4       5-24-2017       Urban   Graduate  ₹ 10,000 - ₹ 20,000
# 4            5       5-24-2017       Rural   Graduate  ₹ 50,000 - ₹ 80,000
#
#   Vote_Now     Past_Vote     CM_satisfaction    MLA_satisfaction  age  \
# 0      BJP           BJP  Fully Dissatisfied  Fully Dissatisfied   26
# 1     RLSP         JD(U)  Somewhat Satisfied  Fully Dissatisfied   34
# 2   JAP(L)           BJP  Fully Dissatisfied  Somewhat Satisfied   25
# 3      RJD           RJD  Fully Dissatisfied  Somewhat Satisfied   36
# 4    JD(U)  Did not vote     Fully Satisfied     Fully Satisfied   22
#
#    age_group gender  assembly_no category    weight
# ...

# %%
data1 = df[(df.age_group >=18 ) & (df.age_group < 25)]
data1
# Out:
#       response_id collection_date urban_rural               education  \
# 4               5       5-24-2017       Rural                Graduate
# 8               9       5-24-2017       Urban               12th Pass
# 14             15       5-24-2017       Rural                Graduate
# 16             17       5-24-2017       Rural       Post - Graduation
# 18             19       5-24-2017       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6858         6859        6-1-2017       Rural                Graduate
# 6859         6860        6-1-2017       Urban       Post - Graduation
# 6861         6862        6-1-2017       Rural                Graduate
# 6864         6865        6-1-2017       Urban                Graduate
# 6865         6866        6-1-2017       Rural  Professional Education
#
#                    income    Vote_Now     Past_Vote        CM_satisfaction  \
# ...

# %%
data1['age_group'] = '18-24'
data1
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8720\85692622.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['age_group'] = '18-24'
#       response_id collection_date urban_rural               education  \
# 4               5       5-24-2017       Rural                Graduate
# 8               9       5-24-2017       Urban               12th Pass
# 14             15       5-24-2017       Rural                Graduate
# 16             17       5-24-2017       Rural       Post - Graduation
# 18             19       5-24-2017       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6858         6859        6-1-2017       Rural                Graduate
# ...

# %%
data2 = df[(df['age'] >=25) & (df['age'] < 40 )]
data2
# Out:
#       response_id collection_date urban_rural  education               income  \
# 0               1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1               2       5-24-2017       Rural   Graduate  ₹ 20,000 - ₹ 30,000
# 2               3       5-24-2017       Rural   Graduate   ₹ 5,000 - ₹ 10,000
# 3               4       5-24-2017       Urban   Graduate  ₹ 10,000 - ₹ 20,000
# 5               6       5-24-2017       Urban   Graduate  ₹ 20,000 - ₹ 30,000
# ...           ...             ...         ...        ...                  ...
# 6855         6856        6-1-2017       Rural  12th Pass   ₹ 5,000 - ₹ 10,000
# 6860         6861        6-1-2017       Rural   Graduate    BPL/Below ₹ 5,000
# 6862         6863        6-1-2017       Rural  10th Pass    BPL/Below ₹ 5,000
# 6863         6864        6-1-2017       Rural   Graduate    BPL/Below ₹ 5,000
# 6866         6867        6-1-2017       Rural  10th Pass   ₹ 5,000 - ₹ 10,000
#
# ...

# %%
data2['age_group'] = '25-40'
data2
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8720\559918449.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2['age_group'] = '25-40'
#       response_id collection_date urban_rural  education               income  \
# 0               1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1               2       5-24-2017       Rural   Graduate  ₹ 20,000 - ₹ 30,000
# 2               3       5-24-2017       Rural   Graduate   ₹ 5,000 - ₹ 10,000
# 3               4       5-24-2017       Urban   Graduate  ₹ 10,000 - ₹ 20,000
# 5               6       5-24-2017       Urban   Graduate  ₹ 20,000 - ₹ 30,000
# ...           ...             ...         ...        ...                  ...
# ...

# %%
data3 = df[(df['age_group'] >= 40) & (df['age_group'] < 55 )]
data3
# Out:
#       response_id collection_date urban_rural          education  \
# 11             12       5-24-2017       Urban           Graduate
# 12             13       5-24-2017       Urban  Post - Graduation
# 28             29       5-24-2017       Rural           Graduate
# 30             31       5-24-2017       Urban           Graduate
# 33             34       5-24-2017       Urban           Graduate
# ...           ...             ...         ...                ...
# 6816         6817        6-1-2017       Rural          12th Pass
# 6819         6820        6-1-2017       Urban          12th Pass
# 6829         6830        6-1-2017       Urban           Graduate
# 6840         6841        6-1-2017       Rural           Graduate
# 6856         6857        6-1-2017       Rural  Post - Graduation
#
#                    income   Vote_Now Past_Vote        CM_satisfaction  \
# 11    ₹ 10,000 - ₹ 20,000        LJP     JD(U)     Somewhat Satisfied
# ...

# %%
data3['age_group'] = '40-55'
data3
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8720\163254026.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data3['age_group'] = '40-55'
#       response_id collection_date urban_rural          education  \
# 11             12       5-24-2017       Urban           Graduate
# 12             13       5-24-2017       Urban  Post - Graduation
# 28             29       5-24-2017       Rural           Graduate
# 30             31       5-24-2017       Urban           Graduate
# 33             34       5-24-2017       Urban           Graduate
# ...           ...             ...         ...                ...
# 6816         6817        6-1-2017       Rural          12th Pass
# ...

# %%
data3
# Out:
#       response_id collection_date urban_rural          education  \
# 11             12       5-24-2017       Urban           Graduate
# 12             13       5-24-2017       Urban  Post - Graduation
# 28             29       5-24-2017       Rural           Graduate
# 30             31       5-24-2017       Urban           Graduate
# 33             34       5-24-2017       Urban           Graduate
# ...           ...             ...         ...                ...
# 6816         6817        6-1-2017       Rural          12th Pass
# 6819         6820        6-1-2017       Urban          12th Pass
# 6829         6830        6-1-2017       Urban           Graduate
# 6840         6841        6-1-2017       Rural           Graduate
# 6856         6857        6-1-2017       Rural  Post - Graduation
#
#                    income   Vote_Now Past_Vote        CM_satisfaction  \
# 11    ₹ 10,000 - ₹ 20,000        LJP     JD(U)     Somewhat Satisfied
# ...

# %%
data4 = df[(df.age_group >= 55)]

# %%
data4.age_group = '55+'
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8720\150729004.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data4.age_group = '55+'

# %%
data4
# Out:
#       response_id collection_date urban_rural               education  \
# 69             70       5-24-2017       Rural                Graduate
# 74             75       5-24-2017       Urban                Graduate
# 121           122       5-24-2017       Rural                Graduate
# 126           127       5-24-2017       Urban                Graduate
# 183           184       5-24-2017       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6649         6650       5-30-2017       Urban                Graduate
# 6702         6703       5-31-2017       Urban  Professional Education
# 6720         6721       5-31-2017       Rural                Graduate
# 6787         6788        6-1-2017       Rural               10th Pass
# 6851         6852        6-1-2017       Urban                Graduate
#
#                      income    Vote_Now     Past_Vote        CM_satisfaction  \
# ...

# %%
df = pd.concat([data1,data2,data3,data4])

# %%
df
# Out:
#       response_id collection_date urban_rural               education  \
# 4               5       5-24-2017       Rural                Graduate
# 8               9       5-24-2017       Urban               12th Pass
# 14             15       5-24-2017       Rural                Graduate
# 16             17       5-24-2017       Rural       Post - Graduation
# 18             19       5-24-2017       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6649         6650       5-30-2017       Urban                Graduate
# 6702         6703       5-31-2017       Urban  Professional Education
# 6720         6721       5-31-2017       Rural                Graduate
# 6787         6788        6-1-2017       Rural               10th Pass
# 6851         6852        6-1-2017       Urban                Graduate
#
#                    income    Vote_Now     Past_Vote        CM_satisfaction  \
# ...

# %%
df.age_group.unique()
# Out:
# array(['18-24', '25-40', '40-55', '55+'], dtype=object)

# %% [markdown]
# ## 5. How many samples were collected for each age group? Which age- group had the most sample?

# %%
df['age_group'].value_counts()
# Out:
# 25-40    3844
# 18-24    2094
# 40-55     801
# 55+       128
# Name: age_group, dtype: int64

# %% [markdown]
# ## 6. What proprtion of the respondents had opted for the RJD party in both the vote_now and the Past vote questions?

# %%
# For vote_now
df.head()
# Out:
#     response_id collection_date urban_rural          education  \
# 4             5       5-24-2017       Rural           Graduate
# 8             9       5-24-2017       Urban          12th Pass
# 14           15       5-24-2017       Rural           Graduate
# 16           17       5-24-2017       Rural  Post - Graduation
# 18           19       5-24-2017       Rural           Graduate
#
#                  income Vote_Now     Past_Vote        CM_satisfaction  \
# 4   ₹ 50,000 - ₹ 80,000    JD(U)  Did not vote        Fully Satisfied
# 8     BPL/Below ₹ 5,000      BJP           BJP        Fully Satisfied
# 14   ₹ 1,50,000 & above      BJP           BJP        Fully Satisfied
# 16    BPL/Below ₹ 5,000      RJD           RJD     Fully Dissatisfied
# 18  ₹ 30,000 - ₹ 50,000   JAP(L)         JD(U)  Somewhat Dissatisfied
#
#       MLA_satisfaction  age age_group gender  assembly_no category    weight
# 4      Fully Satisfied   22     18-24   Male          176       BC  0.333505
# ...

# %%
df['Vote_Now'].value_counts()
# Out:
# BJP           2367
# RJD           1996
# JD(U)          526
# NOTA           458
# JAP(L)         313
# Plurals        217
# INC            216
# Undecided      164
# RJJP           142
# LJP            102
# Others          87
# RLSP            82
# Left Front      79
# AIMIM           37
# VIP             28
# AAP             27
# BSP             15
# HAM             11
# Name: Vote_Now, dtype: int64

# %%
df['Past_Vote'].value_counts()
# Out:
# BJP             2823
# JD(U)           1374
# RJD             1047
# Did not vote     804
# INC              213
# NOTA             167
# Others           132
# LJP              125
# HAM               50
# RLSP              49
# JAP(L)            42
# Left Front        30
# BSP                9
# VIP                2
# Name: Past_Vote, dtype: int64

# %%
df[df['Vote_Now']=='RJD']
# Out:
#       response_id collection_date urban_rural               education  \
# 16             17       5-24-2017       Rural       Post - Graduation
# 38             39       5-24-2017       Urban                Graduate
# 47             48       5-24-2017       Urban                Graduate
# 85             86       5-24-2017       Rural               12th Pass
# 107           108       5-24-2017       Urban               12th Pass
# ...           ...             ...         ...                     ...
# 5830         5831       5-30-2017       Urban                Graduate
# 6095         6096       5-24-2017       Rural                Graduate
# 6123         6124       5-24-2017       Urban  Professional Education
# 6151         6152       5-24-2017       Rural                Graduate
# 6579         6580       5-29-2017       Rural                Graduate
#
#                    income Vote_Now     Past_Vote        CM_satisfaction  \
# ...

# %%
df[(df['Vote_Now']=='RJD') & (df['Past_Vote']=='RJD')]
# Out:
#       response_id collection_date urban_rural          education  \
# 16             17       5-24-2017       Rural  Post - Graduation
# 38             39       5-24-2017       Urban           Graduate
# 47             48       5-24-2017       Urban           Graduate
# 85             86       5-24-2017       Rural          12th Pass
# 120           121       5-24-2017       Rural           Graduate
# ...           ...             ...         ...                ...
# 4753         4754       5-26-2017       Rural  Post - Graduation
# 5493         5494       5-26-2017       Urban           Graduate
# 5687         5688       5-29-2017       Urban           Graduate
# 5830         5831       5-30-2017       Urban           Graduate
# 6151         6152       5-24-2017       Rural           Graduate
#
#                    income Vote_Now Past_Vote        CM_satisfaction  \
# 16      BPL/Below ₹ 5,000      RJD       RJD     Fully Dissatisfied
# ...

# %%
811/6867*100
# Out:
# 11.810106305519149

# %% [markdown]
# ## 7. For Each Day of sample collection, determine the proportion of respondents who were fully satisfied with the performance of the CM. So if there were a total of 1000 samples on day1 and 300 out of those said they were fully satisfied, then our answer for that day would be 0.3

# %%
cm = df[df['CM_satisfaction']=='Fully Satisfied']
cm
# Out:
#       response_id collection_date urban_rural          education  \
# 4               5       5-24-2017       Rural           Graduate
# 8               9       5-24-2017       Urban          12th Pass
# 14             15       5-24-2017       Rural           Graduate
# 75             76       5-24-2017       Rural           Graduate
# 90             91       5-24-2017       Rural           Graduate
# ...           ...             ...         ...                ...
# 6498         6499       5-28-2017       Urban  Post - Graduation
# 6499         6500       5-28-2017       Rural           Graduate
# 6513         6514       5-28-2017       Urban  Post - Graduation
# 6787         6788        6-1-2017       Rural          10th Pass
# 6851         6852        6-1-2017       Urban           Graduate
#
#                      income Vote_Now     Past_Vote  CM_satisfaction  \
# 4       ₹ 50,000 - ₹ 80,000    JD(U)  Did not vote  Fully Satisfied
# ...

# %%
cm['collection_date'].value_counts()
# Out:
# 5-24-2017    146
# 5-25-2017     95
# 5-28-2017     92
# 6-1-2017      75
# 5-29-2017     73
# 5-30-2017     65
# 5-31-2017     62
# 5-26-2017     59
# 5-27-2017     54
# Name: collection_date, dtype: int64

# %%
a = cm['collection_date'].value_counts()
a
# Out:
# 5-24-2017    146
# 5-25-2017     95
# 5-28-2017     92
# 6-1-2017      75
# 5-29-2017     73
# 5-30-2017     65
# 5-31-2017     62
# 5-26-2017     59
# 5-27-2017     54
# Name: collection_date, dtype: int64

# %%
b = df['collection_date'].value_counts()
b
# Out:
# 5-24-2017    1479
# 5-25-2017     998
# 5-28-2017     761
# 5-27-2017     665
# 5-29-2017     620
# 6-1-2017      607
# 5-26-2017     598
# 5-30-2017     582
# 5-31-2017     557
# Name: collection_date, dtype: int64

# %%
c = (a/b)*100
c
# Out:
# 5-24-2017     9.871535
# 5-25-2017     9.519038
# 5-26-2017     9.866221
# 5-27-2017     8.120301
# 5-28-2017    12.089356
# 5-29-2017    11.774194
# 5-30-2017    11.168385
# 5-31-2017    11.131059
# 6-1-2017     12.355848
# Name: collection_date, dtype: float64

# %%
c_df = pd.DataFrame(c)
c_df
# Out:
#            collection_date
# 5-24-2017         9.871535
# 5-25-2017         9.519038
# 5-26-2017         9.866221
# 5-27-2017         8.120301
# 5-28-2017        12.089356
# 5-29-2017        11.774194
# 5-30-2017        11.168385
# 5-31-2017        11.131059
# 6-1-2017         12.355848

# %%
MLA = df[df['MLA_satisfaction']=='Fully Dissatisfied']
MLA
# Out:
#       response_id collection_date urban_rural               education  \
# 8               9       5-24-2017       Urban               12th Pass
# 14             15       5-24-2017       Rural                Graduate
# 18             19       5-24-2017       Rural                Graduate
# 45             46       5-24-2017       Rural                Graduate
# 47             48       5-24-2017       Urban                Graduate
# ...           ...             ...         ...                     ...
# 6379         6380       5-27-2017       Rural       Post - Graduation
# 6499         6500       5-28-2017       Rural                Graduate
# 6550         6551       5-29-2017       Urban       Post - Graduation
# 6579         6580       5-29-2017       Rural                Graduate
# 6702         6703       5-31-2017       Urban  Professional Education
#
#                    income Vote_Now Past_Vote        CM_satisfaction  \
# ...

# %%
MLA['collection_date'].value_counts()
# Out:
# 5-24-2017    887
# 5-25-2017    630
# 5-28-2017    462
# 5-27-2017    403
# 6-1-2017     385
# 5-30-2017    361
# 5-26-2017    353
# 5-29-2017    350
# 5-31-2017    321
# Name: collection_date, dtype: int64

# %%
d = MLA['collection_date'].value_counts()
d
# Out:
# 5-24-2017    887
# 5-25-2017    630
# 5-28-2017    462
# 5-27-2017    403
# 6-1-2017     385
# 5-30-2017    361
# 5-26-2017    353
# 5-29-2017    350
# 5-31-2017    321
# Name: collection_date, dtype: int64

# %%
e = df['collection_date'].value_counts()
e
# Out:
# 5-24-2017    1479
# 5-25-2017     998
# 5-28-2017     761
# 5-27-2017     665
# 5-29-2017     620
# 6-1-2017      607
# 5-26-2017     598
# 5-30-2017     582
# 5-31-2017     557
# Name: collection_date, dtype: int64

# %%
f = d/e * 100
f
# Out:
# 5-24-2017    59.972955
# 5-25-2017    63.126253
# 5-26-2017    59.030100
# 5-27-2017    60.601504
# 5-28-2017    60.709593
# 5-29-2017    56.451613
# 5-30-2017    62.027491
# 5-31-2017    57.630162
# 6-1-2017     63.426689
# Name: collection_date, dtype: float64

# %%
g=pd.DataFrame(f)
g
# Out:
#            collection_date
# 5-24-2017        59.972955
# 5-25-2017        63.126253
# 5-26-2017        59.030100
# 5-27-2017        60.601504
# 5-28-2017        60.709593
# 5-29-2017        56.451613
# 5-30-2017        62.027491
# 5-31-2017        57.630162
# 6-1-2017         63.426689

# %%
g.collection_date.plot()
plt.xticks(rotation='vertical')
plt.xlabels=('Date')
plt.ylabels=('Disstisfaction Percent')
plt.show()

# %% [markdown]
# ## 9. Create a pivot table with index as past_vote, column as vote now and cell values as the count of samples.

# %%
df.pivot_table(index='Past_Vote',columns='Vote_Now',aggfunc = 'count')
# Out:
#              CM_satisfaction                                              \
# Vote_Now                 AAP AIMIM     BJP  BSP  HAM   INC JAP(L)  JD(U)
# Past_Vote
# BJP                      7.0   1.0  1630.0  3.0  5.0  42.0  101.0  110.0
# BSP                      NaN   1.0     2.0  5.0  NaN   1.0    NaN    NaN
# Did not vote             8.0   5.0   231.0  2.0  1.0  22.0   41.0   69.0
# HAM                      2.0   NaN    25.0  NaN  1.0   NaN    3.0    2.0
# INC                      NaN   6.0     6.0  NaN  NaN  57.0   10.0    9.0
# JAP(L)                   NaN   NaN     4.0  NaN  NaN   NaN   35.0    NaN
# JD(U)                    6.0  10.0   254.0  2.0  2.0  45.0   72.0  279.0
# LJP                      NaN   NaN    76.0  1.0  NaN   4.0    3.0    6.0
# Left Front               NaN   1.0     2.0  NaN  NaN   1.0    NaN    NaN
# NOTA                     NaN   1.0    29.0  1.0  NaN   9.0    7.0    7.0
# Others                   1.0   5.0    45.0  1.0  1.0   4.0    7.0    4.0
# ...

# %% [markdown]
# ## 10. Same As aboe but use weight

# %%
df.pivot_table(index='Past_Vote',columns='Vote_Now',values = 'weight', aggfunc='sum')
# Out:
# Vote_Now            AAP      AIMIM          BJP        BSP        HAM  \
# Past_Vote
# BJP            4.807335   0.349996  1049.344112   0.452551  10.171283
# BSP                 NaN   1.654731     5.174487  32.010277        NaN
# Did not vote   8.865896   5.379527   114.203906   3.329611   2.497170
# HAM            0.312607        NaN    25.348884        NaN   1.648856
# INC                 NaN  11.105958     1.642875        NaN        NaN
# JAP(L)              NaN        NaN     6.512846        NaN        NaN
# JD(U)         12.457216  29.198610   156.243100  11.005903   2.639574
# LJP                 NaN        NaN    85.010450   2.481377        NaN
# Left Front          NaN   2.298223     0.209586        NaN        NaN
# NOTA                NaN   1.061204    12.685435   0.051485        NaN
# Others        13.661335  21.212705    34.866218   0.684568   1.505864
# RJD            5.515847  24.149369    32.285093        NaN   0.960400
# ...

# %% [markdown]
# ## 11. Create a dataframe by performing a group by over age_group and calculate the count of total samples under each age_group

# %%
df.groupby('age_group').count()
# Out:
#            response_id  collection_date  urban_rural  education  income  \
# age_group
# 18-24             2094             2094         2094       2094    2094
# 25-40             3844             3844         3844       3844    3844
# 40-55              801              801          801        801     801
# 55+                128              128          128        128     128
#
#            Vote_Now  Past_Vote  CM_satisfaction  MLA_satisfaction   age  \
# age_group
# 18-24          2094       2094             2094              2094  2094
# 25-40          3844       3844             3844              3844  3844
# 40-55           801        801              801               801   801
# 55+             128        128              128               128   128
#
#            gender  assembly_no  category  weight
# age_group
# 18-24        2094         2094      2094    2094
# 25-40        3844         3844      3844    3844
# 40-55         801          801       801     801
# ...

# %%
df1 = df.groupby('age_group').count()
df
# Out:
#       response_id collection_date urban_rural               education  \
# 4               5       5-24-2017       Rural                Graduate
# 8               9       5-24-2017       Urban               12th Pass
# 14             15       5-24-2017       Rural                Graduate
# 16             17       5-24-2017       Rural       Post - Graduation
# 18             19       5-24-2017       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6649         6650       5-30-2017       Urban                Graduate
# 6702         6703       5-31-2017       Urban  Professional Education
# 6720         6721       5-31-2017       Rural                Graduate
# 6787         6788        6-1-2017       Rural               10th Pass
# 6851         6852        6-1-2017       Urban                Graduate
#
#                    income    Vote_Now     Past_Vote        CM_satisfaction  \
# ...

# %% [markdown]
# ## 12. Create a dataframe by performing a group by over age_group and finding the count of total samples for each age_group that opted for the JDU party in Vote Now.

# %%
df.head()
# Out:
#     response_id collection_date urban_rural          education  \
# 4             5       5-24-2017       Rural           Graduate
# 8             9       5-24-2017       Urban          12th Pass
# 14           15       5-24-2017       Rural           Graduate
# 16           17       5-24-2017       Rural  Post - Graduation
# 18           19       5-24-2017       Rural           Graduate
#
#                  income Vote_Now     Past_Vote        CM_satisfaction  \
# 4   ₹ 50,000 - ₹ 80,000    JD(U)  Did not vote        Fully Satisfied
# 8     BPL/Below ₹ 5,000      BJP           BJP        Fully Satisfied
# 14   ₹ 1,50,000 & above      BJP           BJP        Fully Satisfied
# 16    BPL/Below ₹ 5,000      RJD           RJD     Fully Dissatisfied
# 18  ₹ 30,000 - ₹ 50,000   JAP(L)         JD(U)  Somewhat Dissatisfied
#
#       MLA_satisfaction  age age_group gender  assembly_no category    weight
# 4      Fully Satisfied   22     18-24   Male          176       BC  0.333505
# ...

# %%
df2 = df[df['Vote_Now']=='JD(U)']
df2
# Out:
#       response_id collection_date urban_rural          education  \
# 4               5       5-24-2017       Rural           Graduate
# 67             68       5-24-2017       Urban          12th Pass
# 75             76       5-24-2017       Rural           Graduate
# 90             91       5-24-2017       Rural           Graduate
# 102           103       5-24-2017       Rural           Graduate
# ...           ...             ...         ...                ...
# 5248         5249       5-24-2017       Urban  Post - Graduation
# 5956         5957        6-1-2017       Urban          12th Pass
# 6341         6342       5-26-2017       Rural  Post - Graduation
# 6499         6500       5-28-2017       Rural           Graduate
# 6787         6788        6-1-2017       Rural          10th Pass
#
#                      income Vote_Now     Past_Vote     CM_satisfaction  \
# 4       ₹ 50,000 - ₹ 80,000    JD(U)  Did not vote     Fully Satisfied
# ...

# %%
data_jdu = df2.groupby('age_group').count()
data_jdu
# Out:
#            response_id  collection_date  urban_rural  education  income  \
# age_group
# 18-24              181              181          181        181     181
# 25-40              264              264          264        264     264
# 40-55               68               68           68         68      68
# 55+                 13               13           13         13      13
#
#            Vote_Now  Past_Vote  CM_satisfaction  MLA_satisfaction  age  \
# age_group
# 18-24           181        181              181               181  181
# 25-40           264        264              264               264  264
# 40-55            68         68               68                68   68
# 55+              13         13               13                13   13
#
#            gender  assembly_no  category  weight
# age_group
# 18-24         181          181       181     181
# 25-40         264          264       264     264
# 40-55          68           68        68      68
# ...

# %% [markdown]
# ## 13. Merge last two dataframes on age group

# %%
pd.merge(df1,data_jdu,on='age_group')
# Out:
#            response_id_x  collection_date_x  urban_rural_x  education_x  \
# age_group
# 18-24               2094               2094           2094         2094
# 25-40               3844               3844           3844         3844
# 40-55                801                801            801          801
# 55+                  128                128            128          128
#
#            income_x  Vote_Now_x  Past_Vote_x  CM_satisfaction_x  \
# age_group
# 18-24          2094        2094         2094               2094
# 25-40          3844        3844         3844               3844
# 40-55           801         801          801                801
# 55+             128         128          128                128
#
#            MLA_satisfaction_x  age_x  ...  income_y  Vote_Now_y  Past_Vote_y  \
# age_group                             ...
# 18-24                    2094   2094  ...       181         181          181
# ...
